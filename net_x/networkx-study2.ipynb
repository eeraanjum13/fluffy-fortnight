# %% [markdown]
# ### Visualization and Practice with this<https://www.youtube.com/watch?v=flwcAf1_1RU>

# %%
import numpy as np
import pandas as pd 
import networkx as nx
import matplotlib.pyplot as plt

# %%
e = [(0,1), (0,2), (0,3),(1,4), (1,5), (0,6), (3,7)]
test = nx.Graph(e)

nx.draw_spring(test)

# %%
nx.draw_circular(test)

# %%
nx.draw_networkx(test)

# %%
nx.spring_layout(test) # nodes as key and
# Out:
# {0: array([ 0.14704676, -0.06624858]),
#  1: array([-0.22110154,  0.39716012]),
#  2: array([ 0.52623052, -0.278476  ]),
#  3: array([ 0.00574549, -0.58059159]),
#  4: array([-0.63613264,  0.51832943]),
#  5: array([-0.23460295,  0.83268557]),
#  6: array([0.50175746, 0.17714105]),
#  7: array([-0.0889431, -1.       ])}

# %%
nx.draw_networkx_nodes(test, nx.spring_layout(test))

# %%
nx.draw_networkx_edges(test, nx.spring_layout(test), style= ':')

# %%
print(nx.degree(test))
# Out:
# [(0, 4), (1, 3), (2, 1), (3, 2), (4, 1), (5, 1), (6, 1), (7, 1)]

# %%
for k, v in nx.degree(test):
    print(k)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
plt.hist([v for k, v in nx.degree(G)])
# Out:
# (array([82., 10.,  4.,  1.,  0.,  1.,  0.,  1.,  0.,  1.]),
#  array([ 2. ,  4.8,  7.6, 10.4, 13.2, 16. , 18.8, 21.6, 24.4, 27.2, 30. ]),
#  <BarContainer object of 10 artists>)

# %%
nx.diameter(test)
# Out:
# 4

# %%
nx.cluster.average_clustering(G)
# Out:
# 0.17757675287642655

# %%
G= nx.barabasi_albert_graph(100,2)

# %%
nx.draw_spring(G)

# %%
nodes = list(range(100))

df = pd.DataFrame({
    "from": np.random.choice(nodes, 100),
    "to": np.random.choice(nodes, 100)
})

df
# Out:
#     from  to
# 0     79  61
# 1     77   9
# 2     63  94
# 3     55  52
# 4     17  21
# ..   ...  ..
# 95    85  37
# 96    62  82
# 97    58  55
# 98    58  13
# 99    97  59
#
# [100 rows x 2 columns]

# %%
G2 = nx.from_pandas_edgelist(df, source= 'from', target= 'to')

G2.nodes(data= True)
# Out:
# NodeDataView({79: {}, 61: {}, 77: {}, 9: {}, 63: {}, 94: {}, 55: {}, 52: {}, 17: {}, 21: {}, 92: {}, 70: {}, 91: {}, 88: {}, 74: {}, 69: {}, 78: {}, 71: {}, 41: {}, 96: {}, 76: {}, 99: {}, 60: {}, 10: {}, 46: {}, 64: {}, 32: {}, 98: {}, 51: {}, 1: {}, 6: {}, 0: {}, 3: {}, 31: {}, 7: {}, 28: {}, 53: {}, 84: {}, 13: {}, 8: {}, 15: {}, 56: {}, 16: {}, 93: {}, 95: {}, 59: {}, 18: {}, 57: {}, 81: {}, 4: {}, 26: {}, 19: {}, 82: {}, 30: {}, 65: {}, 54: {}, 89: {}, 33: {}, 25: {}, 44: {}, 40: {}, 66: {}, 50: {}, 75: {}, 80: {}, 49: {}, 67: {}, 38: {}, 83: {}, 68: {}, 45: {}, 14: {}, 20: {}, 47: {}, 22: {}, 97: {}, 42: {}, 35: {}, 12: {}, 39: {}, 72: {}, 23: {}, 73: {}, 87: {}, 86: {}, 90: {}, 27: {}, 85: {}, 37: {}, 62: {}, 58: {}})

# %%
nx.draw_kamada_kawai(G2)

# %%
plt.hist([v for k, v in nx.degree(G2)])
# Out:
# (array([24., 41.,  0., 16.,  0.,  6.,  3.,  0.,  0.,  1.]),
#  array([1. , 1.6, 2.2, 2.8, 3.4, 4. , 4.6, 5.2, 5.8, 6.4, 7. ]),
#  <BarContainer object of 10 artists>)
